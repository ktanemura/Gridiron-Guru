# %%
import numpy as np
import sklearn as sk
import requests
from bs4 import BeautifulSoup
import pandas as pd
import sqlite3
from sqlite_api import *
from sklearn import linear_model

# %% [raw]
# TABLE PlayerSeason
#      (Player VARCHAR(40),
#      Team VARCHAR(3),
#      Plays SMALLINT,
#      Fantasy SMALLINT,
#      Games SMALLINT,
#      FPG DECIMAL(5,2),
#      RushAttempts SMALLINT,
#      RushYrds SMALLINT,
#      RushTDs SMALLINT,
#      PassAttempts SMALLINT,
#      Complete SMALLINT,
#      PassYrds SMALLINT,
#      PassTDs SMALLINT,
#      Fumbles SMALLINT,
#      Interceptions SMALLINT,
#      Position CHARACTER(2),
#      Season CHARACTER(4))
#
# TABLE OffenseSeason
#     (Team VARCHAR(3),
#      Season CHARACTER(4),
#      Yards SMALLINT,
#      Rushes SMALLINT,
#      Passes SMALLINT,
#      Incompletes SMALLINT,
#      PassYrds SMALLINT,
#      RushYrds SMALLINT,
#      PassTDs SMALLINT,
#      RushTDs SMALLINT,
#      TDs SMALLINT,
#      Plays SMALLINT,
#      UNIQUE (Team, Season))
#
# TABLE DefenseSeason
#     (City VARCHAR(20),
#     Team VARCHAR(3),
#     Fantasy SMALLINT,
#     Games SMALLINT,
#     FPG DECIMAL(5,2),
#     Sacks SMALLINT,
#     FRecoveries SMALLINT,
#     Interceptions SMALLINT,
#     TDs SMALLINT,
#     Safeties SMALLINT,
#     RushYrdsAllowed SMALLINT,
#     PassYrdsAllowed SMALLINT,
#     TotalYrdsAllowed SMALLINT,
#     Position CHARACTER(2),
#     Season CHARACTER(4)
#
# TABLE KickerSeason
#     (Player VARCHAR(40),
#     Team VARCHAR(3),
#     Fantasy SMALLINT,
#     Games SMALLINT,
#     FPG DECIMAL(5,2),
#     FGoals SMALLINT,
#     FGoalsMissed SMALLINT,
#     ExtraPoints SMALLINT,
#     ExtraPointsMissed SMALLINT,
#     Position CHARACTER(2),
#     Season CHARACTER(4))

# %%
fdb = 'fantasy.db'

player_lbls = ['Player', 'Position', 'Team', 'Season', 'Plays', 'Games', 'RushAttempts', 
              'RushYrds', 'RushTDs', 'PassAttempts', 'Complete', 'PassYrds', 'PassTDs', 'Fumbles', 'Interceptions']

# %%
## Scoring metrics

qb = {'PassYrds': 0.04, # QBs get 0.04 points per passing yard 
        'PassTDs': 4, 
        'Interceptions': -2,
        'RushYrds': 0.1,
        'RushTDs': 6,
        'Fumbles': -2}

wr = {'PassYrds': 0.01,
         'PassTDs': 6,
         'Interceptions': -2,
         'RushYrds': 0.1,
         'RushTDs': 6,
         'Fumbles': -2}

rb = wr.copy()

te = wr.copy()

scores = {'QB': qb,
             'RB': rb,
             'WR': wr,
             'TE': te}

# need 2 points for 2point conversions

# %%
def score_row(row, qb_scores, wr_scores, rb_scores, te_scores):
    score = 0
    if row['Position'] == 'QB':
        metrics = qb_scores
    elif row['Position'] == 'WR':
        metrics = wr_scores
    elif row['Position'] == 'RB':
        metrics = rb_scores
    elif row['Position'] == 'TE':
        metrics = te_scores
    
    for var in metrics:
        score += row[var] * metrics[var]
        
    return score

# %%
select_to_df(fdb, 'OffenseSeason', ['Team', 'Season', 'Yards']).tail()
# Out:
#    Team Season   Yards
# 91  SEA   2014  6414.0
# 92   SF   2014  5771.0
# 93   TB   2014  5215.0
# 94  TEN   2014  5159.0
# 95  WAS   2014  6177.0

# %%
plyr = select_to_df(fdb, 'PlayerSeason', player_lbls, where='WHERE Season=2016')

# %%
# create 2016 mock season database
rdb = 'rankings.db'
conn = sqlite3.connect(rdb)
c = conn.cursor()

# %%
c.execute('DROP TABLE Kickers')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-95-28c9c9eb1216> in <module>()
# ----> 1 c.execute('DROP TABLE Kickers')
#
# OperationalError: no such table: Kickers

# %%
for pos in ['Quarterbacks', 'RunningBacks', 'WideReceivers', 'TightEnds', 'Kickers']:
    c.execute('''CREATE Table ''' + pos +
                '''(Player VARCHAR(30),
                    Team VARCHAR(3),
                    Position CHARACTER(2),
                    PRIMARY KEY (Player))''')

# %%
c.execute('''CREATE Table Defenses
                (Team VARCHAR(3),
                Position CHARACTER(2),
                PRIMARY KEY (Team))''')

# %%
df = select_to_df(fdb, 'PlayerSeason', player_lbls, where='WHERE Season=2016')[['Player', 'Position', 'Team']]
QBs = df[df.Position == 'QB']
for idx in range(len(QBs)):
    row = df.iloc[idx]
    c.execute('INSERT INTO Quarterbacks VALUES (?, ?, ?)', (row[0], row[2], row[1]))

# %%
RBs = df[df.Position == 'RB']
for idx in range(len(RBs)):
    row = df.iloc[idx]
    c.execute('INSERT INTO RunningBacks VALUES (?, ?, ?)', (row[0], row[2], row[1]))

# %%
WRs = df[df.Position == 'WR']
for idx in range(len(WRs)):
    row = df.iloc[idx]
    c.execute('INSERT INTO WideReceivers VALUES (?, ?, ?)', (row[0], row[2], row[1]))

# %%
TEs = df[df.Position == 'TE']
for idx in range(len(TEs)):
    row = df.iloc[idx]
    c.execute('INSERT INTO TightEnds VALUES (?, ?, ?)', (row[0], row[2], row[1]))

# %%
df = select_to_df(fdb, 'KickerSeason', ['Player', 'Team', 'Position'], 'WHERE Season = 2016')
for idx in range(len(df)):
    c.execute('INSERT INTO Kickers VALUES (?, ?, ?)', df.iloc[idx])

# %%
df = select_to_df(fdb, 'DefenseSeason', ['Team', 'Position'], 'WHERE Season = 2016')
for idx in range(len(df)):
    c.execute('INSERT INTO Defenses VALUES (?, ?)', df.iloc[idx])

# %%
df = select_to_df(fdb, 'PlayerSeason', player_lbls, 'WHERE Season != 2016')
df['Score'] = ply.apply(score_row, args=(qb, wr, rb, te), axis=1)

# %%
for i in ply.Team.unique:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-632ca048a885> in <module>()
# ----> 1 for i in ply.Team.unique:
#       2     print(i)
#
# TypeError: 'method' object is not iterable

# %% [markdown]
# ## Offensive Features

# %%
def add_feature(df, name, func):
    df[name] = df.apply(func, axis=1)
    return df

# %%
offense_lbls = ['Team', 
                 'Season', 
                 'Yards',
                 'PassYrds',
                 'RushYrds',
                 'Points']

# %%
def pass_rush_rat(row):
    return row['PassYrds'] / row['RushYrds']

def yards_per_game(row):
    return row['Yards'] / 16

def pass_yrds_per_game(row):
    return row['PassYrds'] / 16

def rush_yrds_per_game(row):
    return row['RushYrds'] / 16

def points_per_game(row):
    return row['Points'] / 16

# %%
off = select_to_df(fdb, 'OffenseSeason', offense_lbls)

# %%
off = add_feature(off, 'OffPassRushRatio', pass_rush_rat)
off = add_feature(off, 'OffYardsPerGame', yards_per_game)
off = add_feature(off, 'OffPassYrdsPerGame', pass_yrds_per_game)
off = add_feature(off, 'OffRushYrdsPerGame', rush_yrds_per_game)
off = add_feature(off, 'OffPointsPerGame', points_per_game)
off = off.drop(['Yards', 'PassYrds', 'RushYrds', 'Points'], axis=1)
off.head()
# Out:
#   Team Season  OffPassRushRatio  OffYardsPerGame  OffPassYrdsPerGame  \
# 0   NE   2007          2.558680         411.2500            295.6875
# 1  DAL   2007          2.351088         365.6875            256.5625
# 2  IND   2007          2.364009         358.6875            252.0625
# 3  JAX   2007          1.391886         357.4375            208.0000
# 4  SEA   2007          2.448425         348.9375            247.7500
#
#    OffRushYrdsPerGame  OffPointsPerGame
# 0            115.5625           36.8125
# 1            109.1250           28.4375
# 2            106.6250           28.1250
# 3            149.4375           25.6875
# 4            101.1875           24.5625

# %% [markdown]
# ## Additional Player Features

# %%
def pass_tdatt_rat(row):
    if row['PassAttempts'] == 0:
        return 0
    return row['PassTDs'] / row['PassAttempts']

def rush_tdatt_rat(row):
    if row['RushAttempts'] == 0:
        return 0
    return row['RushTDs'] / row['RushAttempts']

def complete_perc(row):
    if row['PassAttempts'] == 0:
        return 0
    return row['Complete'] / row['PassAttempts']

def avg_rush_yrds(row):
    if row['RushAttempts'] == 0:
        return 0
    return row['RushYrds'] / row['RushAttempts']

def avg_pass_yrds(row):
    if row['PassAttempts'] == 0:
        return 0
    return row['PassYrds'] / row['PassAttempts']

def avg_plays(row):
    return row['Plays'] / row['Games']

def score_per_play(row):
    return row['Score'] / row['Plays']

def score_per_game(row):
    return row['Score'] / row['Games']

def games_perc(row):
    return row['Games'] / 16

def intercept_rat(row):
    if row['PassAttempts'] == 0:
        return 0
    return row['Interceptions'] / row['PassAttempts']

def pass_att_per_game(row):
    return row['PassAttempts'] / row['Games']

def rush_att_per_game(row):
    return row['RushAttempts'] / row['Games']

def fumb_per_game(row):
    return row['Fumbles'] / row['Games']

# %%
df = select_to_df(fdb, 'PlayerSeason', player_lbls)
df['PassTDAttRatio'] = df.apply(pass_tdatt_rat, axis=1)
df['RushTDAttRatio'] = df.apply(rush_tdatt_rat, axis=1)
df['AvgPassYrds'] = df.apply(avg_pass_yrds, axis=1)
df['AvgRushYrds'] = df.apply(avg_rush_yrds, axis=1)
df['PercentComplete'] = df.apply(complete_perc, axis=1)
df['PlaysPerGame'] = df.apply(avg_plays, axis=1)
df['GamesPlayedPercent'] = df.apply(games_perc, axis=1)
df['InterceptionRatio'] = df.apply(intercept_rat, axis=1)
df['PassAttPerGame'] = df.apply(pass_att_per_game, axis=1)
df['RushAttPerGame'] = df.apply(rush_att_per_game, axis=1)
df['FumblesPerGame'] = df.apply(fumb_per_game, axis=1)
#df['ScorePerPlay'] = df.apply(score_per_play, axis=1)
#df['ScorePerGame'] = df.apply(score_per_game, axis=1)

# %%
df[(df.RushAttempts > 0) & (df.Position == 'TE')].sort_values('RushAttempts', ascending=False)
# Out:
#                    Player Position Team Season  Plays  Games  RushAttempts  \
# 4163         Charles Clay       TE  MIA   2013  107.0   16.0           7.0
# 4241        MarQueis Gray       TE  CLE   2013   15.0   12.0           6.0
# 4804          Trey Burton       TE  PHI   2014    5.0   15.0           5.0
# 3076      Aaron Hernandez       TE   NE   2011  118.0   14.0           5.0
# 1569           Jeff Dugan       TE  MIN   2008    6.0    9.0           4.0
# 2042       Delanie Walker       TE   SF   2009   36.0   16.0           3.0
# 2547      Aaron Hernandez       TE   NE   2010   67.0   14.0           3.0
# 2573       Delanie Walker       TE   SF   2010   48.0   14.0           3.0
# 988           Kris Wilson       TE   KC   2007   53.0   16.0           3.0
# 3644         Dwayne Allen       TE  IND   2012   69.0   16.0           3.0
# 3111       Delanie Walker       TE   SF   2011   39.0   15.0           3.0
# 3142       Richie Brockel       TE  CAR   2011    6.0   11.0           3.0
# 2056           Jeff Dugan       TE  MIN   2009    9.0   16.0           3.0
# 2622           Jeff Dugan       TE  MIN   2010    7.0   16.0           2.0
# 2578          Zach Miller       TE  JAC   2010   28.0   15.0           2.0
# 3081         Vernon Davis       TE   SF   2011   97.0   16.0           2.0
# 3147         Chris Cooley       TE  WAS   2011   15.0    5.0           2.0
# 5359        David Johnson       TE  LAC   2015    4.0   16.0           2.0
# 437          Vernon Davis       TE   SF   2006   44.0   10.0           2.0
# 4765         Virgil Green       TE  DEN   2014    8.0   13.0           2.0
# 2003         Dallas Clark       TE  IND   2009  134.0   16.0           2.0
# 1523       Delanie Walker       TE   SF   2008   18.0   15.0           2.0
# 950          Dallas Clark       TE  IND   2007  102.0   15.0           2.0
# 1022           Jeff Dugan       TE  MIN   2007   10.0   16.0           2.0
# 4752       Garrett Graham       TE  HOU   2014   29.0   11.0           1.0
# 5282         Heath Miller       TE  PIT   2015   82.0   15.0           1.0
# 3666           Fred Davis       TE  WAS   2012   32.0    7.0           1.0
# 3673           Niles Paul       TE  WAS   2012   16.0   16.0           1.0
# 5319         Dwayne Allen       TE  IND   2015   30.0   13.0           1.0
# 3682      Dorin Dickerson       TE  BUF   2012   16.0   10.0           1.0
# ...                   ...      ...  ...    ...    ...    ...           ...
# 4718           Jared Cook       TE  LAR   2014   94.0   16.0           1.0
# 4724       Timothy Wright       TE   NE   2014   34.0   16.0           1.0
# 3654          James Casey       TE  HOU   2012   46.0   16.0           1.0
# 431             Bo Scaife       TE  TEN   2006   57.0   14.0           1.0
# 3637      Aaron Hernandez       TE   NE   2012   84.0   10.0           1.0
# 5227  Connor Hamlett       TE  CLE   2016    1.0    3.0           0.0
# 5228  Randall Telfer       TE  CLE   2016    7.0   14.0           0.0
#
#       RushYrds  RushTDs  PassAttempts        ...         GamesPlayedPercent  \
# 5224       0.0      0.0           5.0        ...                     0.5625
# 5225       0.0      0.0          82.0        ...                     1.0000
# 5226       0.0      0.0          12.0        ...                     0.7500
# 5227       0.0      0.0           1.0        ...                     0.1875
# 5228       0.0      0.0           7.0        ...                     0.8750
#
#       InterceptionRatio  PassAttPerGame  RushAttPerGame  FumblesPerGame  \
# 5224                0.0        0.555556             0.0             0.0
# 5225                0.0        5.125000             0.0             0.0
# 5226                0.0        1.000000             0.0             0.0
# 5227                0.0        0.333333             0.0             0.0
# 5228                0.0        0.500000             0.0             0.0
#
#       OffPassRushRatio  OffYardsPerGame  OffPassYrdsPerGame  \
# 5224          1.906542            311.0               204.0
# 5225          1.906542            311.0               204.0
# 5226          1.906542            311.0               204.0
# 5227          1.906542            311.0               204.0
# 5228          1.906542            311.0               204.0
#
#       OffRushYrdsPerGame  OffPointsPerGame
# 5224               107.0              16.5
# 5225               107.0              16.5
# 5226               107.0              16.5
# 5227               107.0              16.5
# 5228               107.0              16.5
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Creating the Models

# %%
# todo: enable interactions
# get rid of zeros
# maybe get dont train on low games played
# maybe binary predict upward trend/downward trend

def create_model(df, pos, predict, features, reg_type='linear'):
    df = df[df.Position == pos]
    left_vars = ['Player', 'Team', 'Season'] + [predict]
    right_vars = ['Player', 'Team', 'Season'] + features
    model_vars = left_vars.copy()
    for var in features:
        model_vars.append('PS' + var)
        
    # build train dataframe
    model_df = pd.DataFrame(columns=model_vars)
    for season in range(2008, 2016):
        prev_season = str(season - 1)
        season = str(season)
        left_df = df[left_vars][df.Season == season]
        right_df = df[right_vars][df.Season == prev_season]
        right_df['Season'] = season
        left_df = pd.merge(left_df, right_df, on=['Player', 'Team', 'Season'])
        left_df.columns = model_vars
        model_df = model_df.append(left_df)
        
    # build test dataframe
    left_df = df[left_vars][df.Season == '2016']
    right_df = df[right_vars][df.Season == '2015']
    right_df['Season'] = '2016'
    test_df = pd.merge(left_df, right_df, on=['Player', 'Team', 'Season'])
    test_df.columns = model_vars
  
    if reg_type == 'linear':
        model = linear_model.LinearRegression()
    elif reg_type == 'logistic':
        model = linear_model.LogisticRegression()
    print(test_df)   
    model.fit(model_df[['PS'+v for v in features]], model_df[predict])
    print(model.coef_)    
    print(model.score(model_df[['PS'+v for v in features]], model_df[predict]))
    return model

mdl = create_model(players, 'QB', 'GamesPlayedPercent', ['GamesPlayedPercent', 'AvgPassYrds', 'PassTDAttRatio', 'PercentComplete', 'OffPassYrdsPerGame'])
# Out:
#                 Player Team Season  GamesPlayedPercent  PSGamesPlayedPercent  \
# 0        Aaron Rodgers   GB   2016              1.0000                1.0000
# 1           Drew Brees   NO   2016              1.0000                0.9375
# 2            Matt Ryan  ATL   2016              1.0000                1.0000
# 3          Andrew Luck  IND   2016              0.9375                0.4375
# 4         Kirk Cousins  WAS   2016              1.0000                1.0000
# 5        Philip Rivers  LAC   2016              1.0000                1.0000
# 6       Kellen Clemens  LAC   2016              0.7500                0.1250
# 7     Matthew Stafford  DET   2016              1.0000                1.0000
# 8            Tony Romo  DAL   2016              0.0625                0.2500
# 9       Jameis Winston   TB   2016              1.0000                1.0000
# 10      Russell Wilson  SEA   2016              1.0000                1.0000
# 11         Andy Dalton  CIN   2016              1.0000                0.8125
# 12      Marcus Mariota  TEN   2016              0.9375                0.7500
# 13       Carson Palmer  ARI   2016              0.9375                1.0000
# 14        Drew Stanton  ARI   2016              0.3125                0.4375
# 15          Cam Newton  CAR   2016              0.9375                1.0000
# 16      Derek Anderson  CAR   2016              0.3125                0.1875
# 17            Joe Webb  CAR   2016              0.8750                1.0000
# 18          Derek Carr  OAK   2016              0.9375                1.0000
# 19        Matt McGloin  OAK   2016              0.2500                0.1250
# 20  Ben Roethlisberger  PIT   2016              0.8750                0.7500
# 21        Landry Jones  PIT   2016              0.5000                0.4375
# 22          Joe Flacco  BAL   2016              1.0000                0.6250
# 23        Tyrod Taylor  BUF   2016              0.9375                0.8750
# 24           EJ Manuel  BUF   2016              0.4375                0.4375
# 25         Eli Manning  NYG   2016              1.0000                1.0000
# 26           Tom Brady   NE   2016              0.7500                1.0000
# 27     Jimmy Garoppolo   NE   2016              0.3750                0.3125
# 28          Shaun Hill  MIN   2016              0.1875                0.1875
# 29          Alex Smith   KC   2016              0.9375                1.0000
# 30      Ryan Tannehill  MIA   2016              0.8125                1.0000
# 31          Matt Moore  MIA   2016              0.3125                0.0625
# 32      Trevor Siemian  DEN   2016              0.8750                0.0625
# 33    Colin Kaepernick   SF   2016              0.7500                0.5625
# 34      Blaine Gabbert   SF   2016              0.3750                0.5000
# 35    Ryan Fitzpatrick  NYJ   2016              0.8750                1.0000
# 36          Geno Smith  NYJ   2016              0.1875                0.0625
# 37         Case Keenum  LAR   2016              0.6250                0.3750
# 38        Sean Mannion  LAR   2016              0.0625                0.0625
# 39          Jay Cutler  CHI   2016              0.3125                0.9375
# 40         Josh McCown  CLE   2016              0.3125                0.5000
#
#     PSAvgPassYrds  PSPassTDAttRatio  PSPercentComplete  PSOffPassYrdsPerGame
# 0        6.680070          0.054196           0.606643              218.9375
# 1        7.767145          0.051037           0.682616              310.6250
# 2        7.477199          0.034202           0.662866              273.6875
# 3        6.419795          0.051195           0.552901              231.5000
# 4        7.672192          0.053407           0.697974              255.9375
# 5        7.249622          0.043873           0.661120              286.9375
# 6       10.500000          0.166667           0.833333              286.9375
# 7        7.199324          0.054054           0.672297              263.2500
# 8        7.305785          0.041322           0.685950              216.9375
# 9        7.555140          0.041121           0.583178              240.7500
# 10       8.331263          0.070393           0.681159              236.8750
# 11       8.419689          0.064767           0.660622              245.1875
# 12       7.616216          0.051351           0.621622              218.9375
# 13       8.698324          0.065177           0.636872              288.5000
# 14       4.160000          0.000000           0.440000              288.5000
# 15       7.735887          0.070565           0.596774              224.3125
# 16       6.000000          0.000000           0.666667              224.3125
# 17       0.000000          0.000000           0.000000              224.3125
# 18       6.958115          0.055846           0.610820              242.4375
# 19       4.437500          0.062500           0.718750              242.4375
# 20       8.396588          0.044776           0.680171              287.6875
# 21       9.327273          0.054545           0.581818              287.6875
# 22       6.757869          0.033898           0.644068              266.9375
# 23       7.986842          0.052632           0.636842              208.9375
# 24       6.678571          0.035714           0.619048              208.9375
# 25       7.177994          0.056634           0.626214              271.6875
# 26       7.644231          0.057692           0.644231              286.6875
# 27       1.500000          0.000000           0.250000              286.6875
# 28       2.142857          0.000000           0.285714              183.0000
# 29       7.417021          0.042553           0.653191              203.4375
# 30       7.180887          0.040956           0.619454              238.1875
# 31      14.000000          0.000000           1.000000              238.1875
# 32       0.000000          0.000000           0.000000              248.1250
# 33       6.618852          0.024590           0.590164              207.2500
# 34       7.202128          0.035461           0.631206              207.2500
# 35       6.948399          0.055160           0.596085              253.5625
# 36       6.309524          0.047619           0.642857              253.5625
# 37       6.624000          0.032000           0.608000              175.3125
# 38       4.428571          0.000000           0.857143              175.3125
# 39       7.575569          0.043478           0.643892              228.9375
# 40       7.222603          0.041096           0.636986              236.3750
# [  5.99603492e-01  -2.31802224e-03   9.84924014e-01  -1.88120899e-01
#    3.37142876e-04]
# 0.375321281966

# %%
players[['Player', 'GamesPlayedPercent', 'AvgPassYrds', 'PassTDAttRatio']][players.Player == 'Tom Brady'].tail()
# Out:
#          Player  GamesPlayedPercent  AvgPassYrds  PassTDAttRatio
# 2609  Tom Brady                1.00     7.577708        0.053375
# 3312  Tom Brady                1.00     6.915605        0.039809
# 3785  Tom Brady                1.00     7.060137        0.056701
# 4164  Tom Brady                1.00     7.644231        0.057692
# 5012  Tom Brady                0.75     8.226852        0.064815

# %%
mdl = create_model(players, 'QB', 'AvgPassYrds', ['AvgPassYrds', 'GamesPlayedPercent'])
# Out:
#                 Player Team Season  AvgPassYrds  PSAvgPassYrds  \
# 0        Aaron Rodgers   GB   2016     7.259016       6.680070
# 1           Drew Brees   NO   2016     7.738484       7.767145
# 2            Matt Ryan  ATL   2016     9.258427       7.477199
# 3          Andrew Luck  IND   2016     7.779817       6.419795
# 4         Kirk Cousins  WAS   2016     8.113861       7.672192
# 5        Philip Rivers  LAC   2016     7.588235       7.249622
# 6       Kellen Clemens  LAC   2016     0.000000      10.500000
# 7     Matthew Stafford  DET   2016     7.284512       7.199324
# 8            Tony Romo  DAL   2016     7.250000       7.305785
# 9       Jameis Winston   TB   2016     7.213404       7.555140
# 10      Russell Wilson  SEA   2016     7.727106       8.331263
# 11         Andy Dalton  CIN   2016     7.470693       8.419689
# 12      Marcus Mariota  TEN   2016     7.596452       7.616216
# 13       Carson Palmer  ARI   2016     7.090452       8.698324
# 14        Drew Stanton  ARI   2016     4.000000       4.160000
# 15          Cam Newton  CAR   2016     6.880392       7.735887
# 16      Derek Anderson  CAR   2016     8.547170       6.000000
# 17            Joe Webb  CAR   2016     0.000000       0.000000
# 18          Derek Carr  OAK   2016     7.030357       6.958115
# 19        Matt McGloin  OAK   2016     3.333333       4.437500
# 20  Ben Roethlisberger  PIT   2016     7.502947       8.396588
# 21        Landry Jones  PIT   2016     6.488372       9.327273
# 22          Joe Flacco  BAL   2016     6.424107       6.757869
# 23        Tyrod Taylor  BUF   2016     6.933486       7.986842
# 24           EJ Manuel  BUF   2016     4.851852       6.678571
# 25         Eli Manning  NYG   2016     6.734114       7.177994
# 26           Tom Brady   NE   2016     8.226852       7.644231
# 27     Jimmy Garoppolo   NE   2016     7.968254       1.500000
# 28          Shaun Hill  MIN   2016     6.914286       2.142857
# 29          Alex Smith   KC   2016     7.161554       7.417021
# 30      Ryan Tannehill  MIA   2016     7.699229       7.180887
# 31          Matt Moore  MIA   2016     8.287356      14.000000
# 32      Trevor Siemian  DEN   2016     6.997942       0.000000
# 33    Colin Kaepernick   SF   2016     6.770393       6.618852
# 34      Blaine Gabbert   SF   2016     5.781250       7.202128
# 35    Ryan Fitzpatrick  NYJ   2016     6.724566       6.948399
# 36          Geno Smith  NYJ   2016     9.000000       6.309524
# 37         Case Keenum  LAR   2016     6.835404       6.624000
# 38        Sean Mannion  LAR   2016     3.166667       4.428571
# 39          Jay Cutler  CHI   2016     7.729927       7.575569
# 40         Josh McCown  CLE   2016     6.666667       7.222603
#
#     PSGamesPlayedPercent
# 0                 1.0000
# 1                 0.9375
# 2                 1.0000
# 3                 0.4375
# 4                 1.0000
# 5                 1.0000
# 6                 0.1250
# 7                 1.0000
# 8                 0.2500
# 9                 1.0000
# 10                1.0000
# 11                0.8125
# 12                0.7500
# 13                1.0000
# 14                0.4375
# 15                1.0000
# 16                0.1875
# 17                1.0000
# 18                1.0000
# 19                0.1250
# 20                0.7500
# 21                0.4375
# 22                0.6250
# 23                0.8750
# 24                0.4375
# 25                1.0000
# 26                1.0000
# 27                0.3125
# 28                0.1875
# 29                1.0000
# 30                1.0000
# 31                0.0625
# 32                0.0625
# 33                0.5625
# 34                0.5000
# 35                1.0000
# 36                0.0625
# 37                0.3750
# 38                0.0625
# 39                0.9375
# 40                0.5000
# [ 0.07797844  1.1068356 ]
# 0.0374659323518

# %%
players.columns
# Out:
# Index(['Player', 'Position', 'Team', 'Season', 'Plays', 'Games',
#        'RushAttempts', 'RushYrds', 'RushTDs', 'PassAttempts', 'Complete',
#        'PassYrds', 'PassTDs', 'Fumbles', 'Interceptions', 'PassTDAttRatio',
#        'RushTDAttRatio', 'AvgPassYrds', 'AvgRushYrds', 'PercentComplete',
#        'PlaysPerGame', 'GamesPlayedPercent', 'InterceptionRatio',
#        'PassAttPerGame', 'RushAttPerGame', 'FumblesPerGame',
#        'OffPassRushRatio', 'OffYardsPerGame', 'OffPassYrdsPerGame',
#        'OffRushYrdsPerGame', 'OffPointsPerGame'],
#       dtype='object')
