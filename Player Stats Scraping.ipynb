# %%
import numpy as np
import sklearn as sk
import requests
from bs4 import BeautifulSoup
import pandas as pd
import sqlite3

# %%
def scrape(season, position):
    # column name for the dataframe to be created
    labels = ['Player', 'Team', 'Plays', 'Fantasy', 'Games', 'FP/G', 'Num Runs', 
              'Run Yrds', 'Run TDs', 'Pass Attempts', 'Complete', 'Pass Yrds', 'Pass TDs', 'Fumbles', 'Interceptions']
    
    # build pandas dataframe for this season's data
    df = pd.DataFrame(columns=labels)
    
    # build url and request html
    url = 'http://thehuddle.com/stats/'+str(season)+'/plays_std.php?pos=' + position
    r  = requests.get(url, headers={'User-agent': 'Mozilla/5.0'})
    contents = BeautifulSoup(r.text, 'lxml')
    
    # hard-coded number of columns in table
    num_cols = 15
    table = contents.find("tbody")
    entries = table.find_all("td")
    
    # find number of rows in the table
    num_rows = int(len(entries)/15)
    
    for rowN in range(num_rows):
        cur_row = dict()
        for colN in range(len(labels)):
            cur_row[labels[colN]] = entries[rowN*num_cols + colN].text.strip()
        cur_row['Season'] = str(season)
        cur_row['Position'] = position
        df = df.append(pd.Series(cur_row), ignore_index=True)
        
    return df
        #print('row ' + str(rowN) +': '+str(cur_row))
    
qb2010 = scrape(2010, 'QB')

# %%
conn = sqlite3.connect('players.db')

c = conn.cursor()

c.execute('''CREATE TABLE PlayerSeason
             (Player VARCHAR(40), 
             Team VARCHAR(3), 
             Plays SMALLINT, 
             Fantasy SMALLINT, 
             Games SMALLINT,
             FPG DECIMAL(5,2),
             NumRuns SMALLINT,
             RunYrds SMALLINT,
             RunTDs SMALLINT,
             PassAttempts SMALLINT, 
             Complete SMALLINT, 
             PassYrds SMALLINT, 
             PassTDs SMALLINT, 
             Fumbles SMALLINT, 
             Interceptions SMALLINT,
             Position CHARACTER(2),
             Season CHARACTER(4),
             UNIQUE (Player, Season, Position, Team))''')

# %%
def update_players(conn, df):
    tuple_list = []
    
    c = conn.cursor()
    for ndx in range(len(df)):
        try:
            c.execute('INSERT INTO PlayerSeason VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)', tuple(df.iloc[ndx])) 
        except:
            print(str(df.iloc[ndx]['Player'])+' '+str(df.iloc[ndx]['Season'])+' already in table')
        
    conn.commit()

# %%
pos = ['QB', 'WR', 'RB', 'TE']

conn = sqlite3.connect('players.db')

# loop through all seasons available
for year in range(2006, 2017):
    # loop through all positions
    for cur_pos in pos:
        print(str(year)+'  '+cur_pos)
        update_players(conn, scrape(year, cur_pos))

conn.close()
# Out:
# 2006  QB
# 2006  WR
# 2006  RB
# 2006  TE
# 2007  QB
# 2007  WR
# 2007  RB
# 2007  TE
# 2008  QB
# 2008  WR
# 2008  RB
# 2008  TE
# 2009  QB
# 2009  WR
# 2009  RB
# 2009  TE
# 2010  QB
# 2010  WR
# 2010  RB
# 2010  TE
# 2011  QB
# 2011  WR
# 2011  RB
# 2011  TE
# 2012  QB
# 2012  WR
# 2012  RB
# 2012  TE
# 2013  QB
# 2013  WR
# 2013  RB
# 2013  TE
# 2014  QB
# 2014  WR
# 2014  RB
# 2014  TE
# 2015  QB
# 2015  WR
# 2015  RB
# 2015  TE
# 2016  QB
# 2016  WR
# 2016  RB
# 2016  TE

# %%
conn.close()

# %%
qb2010
# Out:
#                 Player Team Plays Fantasy Games   FP/G Num Runs Run Yrds  \
# 0       Peyton Manning  IND   697     369    16  23.05       18       18
# 1        Aaron Rodgers   GB   539     368    15  24.51       64      356
# 2           Drew Brees   NO   677     363    16  22.67       18       -3
# 3        Philip Rivers   SD   570     361    16  22.54       29       52
# 4         Michael Vick  PHI   472     356    12  29.71      100      676
# 5            Tom Brady   NE   523     348    16  21.75       31       30
# 6          Eli Manning  NYG   571     331    16  20.69       32       70
# 7          Matt Schaub  HOU   596     317    16  19.83       22       28
# 8            Matt Ryan  ATL   617     309    16  19.34       46      122
# 9         Josh Freeman   TB   542     309    16  19.31       68      364
# 10       Carson Palmer  CIN   618     308    16  19.22       32       50
# 11          Joe Flacco  BAL   532     296    16  18.47       43       84
# 12       David Garrard  JAC   432     287    14  20.47       66      279
# 13          Jay Cutler  CHI   482     285    15  18.99       50      232
# 14         Matt Cassel   KC   483     276    15  18.42       33      125
# 15          Kyle Orton  DEN   520     272    13  20.96       22       98
# 16    Ryan Fitzpatrick  BUF   481     269    13  20.68       40      269
# 17        Mark Sanchez  NYJ   537     261    16  16.32       30      105
# 18        Sam Bradford   LA   617     260    16  16.24       27       63
# 19  Ben Roethlisberger  PIT   423     258    12  21.47       34      176
# 20      Donovan McNabb  WAS   501     240    13  18.46       29      151
# 21          Chad Henne  MIA   525     230    15  15.35       35       52
# 22     Matt Hasselbeck  SEA   467     222    14  15.86       23       60
# 23          Shaun Hill  DET   438     211    11  19.15       22      123
# 24           Jon Kitna  DAL   349     203    10  20.30       31      147
# 25      Jason Campbell  OAK   376     200    13  15.35       47      222
# 26          Alex Smith   SF   360     180    11  16.41       18       60
# 27         Brett Favre  MIN   375     170    13  13.10       17        8
# 28       Kerry Collins  TEN   288     147    10  14.72       10        1
# 29      Derek Anderson  ARI   332     134    12  11.15        5       25
# ..                 ...  ...   ...     ...   ...    ...      ...      ...
# 50    Tarvaris Jackson  MIN    65      35     3  11.78        7       63
# 51       Charlie Batch  PIT    56      33     3  10.87        7       30
# 52       Stephen McGee  DAL    57      27     2  13.65       13       74
# 53            Max Hall  ARI    79      22     6   3.67        1       -5
# 54         Todd Bouman  JAC    36      20     1  19.90        2        8
# 55        Dennis Dixon  PIT    37      16     2   7.95        5       32
# 56        Mark Brunell  NYJ    13      14     2   6.92        0        0
# 57    Brian St. Pierre  CAR    28      13     1  12.65        0        0
# 58         Rusty Smith  TEN    40      10     2   5.00        0        0
# 59        Josh Johnson   TB    21       9    11   0.86        4       39
# 60         Brian Hoyer   NE    25       9     5   1.86       10       -8
# 61      Richard Bartel  ARI    28       8     1   7.50        0        0
# 62      Kellen Clemens  NYJ     4       7     1   7.20        2        9
# 63         Luke McCown  JAC    20       6     1   6.40        1        4
# 64         Brian Brohm  BUF    23       5     1   5.30        0        0
# 65        Todd Collins  CHI    27       3     2   1.70        0        0
# 66          David Carr   SF    13       3     1   3.35        0        0
# 67         Kyle Boller  OAK    11       3     5   0.61        7       18
# 68         Caleb Hanie  CHI     8       3     2   1.32        1       -1
# 69        Chase Daniel   NO     5       2    13   0.18        2       16
# 70           Tony Pike  CAR    12       2     1   2.35        0        0
# 71         Tyler Palko   KC     8       2     2   1.12        2        5
# 72      Byron Leftwich  PIT     7       2     1   2.10        0        0
# 73       Brodie Croyle   KC    19       2     2   0.95        0        0
# 74          Levi Brown  BUF     3       1     1   1.20        0        0
# 75     Chad Pennington  MIA     2       1     1   0.95        0        0
# 76       Jordan Palmer  CIN     3       1     1   0.90        0        0
# 77        Chris Redman  ATL     7       1     2   0.45        1       -1
# 78         Billy Volek   SD     7      -0     3  -0.03        6       -5
# 79      Sage Rosenfels  NYG     3      -0    12  -0.03        3       -3
#
#    Run TDs Pass Attempts Complete Pass Yrds Pass TDs Fumbles Interceptions  \
# 0        0           679      450      4700       33       1            17
# 1        4           475      312      3922       28       1            11
# 2        0           658      448      4620       33       2            22
# 3        0           541      357      4710       30       4            13
# 4        9           372      233      3018       21       3             6
# 5        1           492      324      3900       36       1             4
# 6        0           539      339      4002       31       5            25
# 7        0           574      365      4370       24       3            12
# 8        0           571      357      3705       28       3             9
# 9        0           474      291      3451       25       3             6
# 10       0           586      362      3970       26       3            20
# 11       1           489      306      3622       25       4            10
# 12       5           366      236      2734       23       4            15
# 13       1           432      261      3274       23       6            16
# 14       0           450      262      3116       27       1             7
# 15       0           498      293      3653       20       4             9
# 16       0           441      255      3000       23       5            15
# 17       3           507      278      3291       17       1            13
# 18       1           590      354      3512       18       2            15
# 19       2           389      240      3200       17       3             5
# 20       0           472      275      3377       14       1            15
# 21       0           490      301      3301       15       2            19
# 22       3           444      266      3001       12       5            17
# 23       0           416      257      2686       16       1            12
# 24       1           318      209      2365       16       1            12
# 25       1           329      194      2387       13       1             8
# 26       0           342      204      2370       14       2            10
# 27       0           358      217      2509       11       5            19
# 28       0           278      160      1823       14       3             8
# 29       0           327      169      2065        7       3            10
# ..     ...           ...      ...       ...      ...     ...           ...
# 50       0            58       34       341        3       0             4
# 51       0            49       29       352        3       0             3
# 52       0            44       22       238        2       0             0
# 53       0            78       39       370        1       2             6
# 54       0            34       18       222        2       0             2
# 55       0            32       22       254        0       1             1
# 56       0            13        7       117        2       0             1
# 57       0            28       13       173        1       0             2
# 58       0            40       20       200        0       0             4
# 59       0            16       14       111        0       0             0
# 60       0            15        7       122        1       0             1
# 61       0            28       16       150        0       0             1
# 62       1             2        1         6        0       0             0
# 63       0            19       11       120        0       0             0
# 64       0            23       10       106        0       1             3
# 65       0            27       10        68        0       0             5
# 66       0            13        5        67        0       0             1
# 67       0             4        2        25        0       0             1
# 68       0             7        5        55        0       0             0
# 69       0             3        2        16        0       0             0
# 70       0            12        6        47        0       0             0
# 71       0             6        4        35        0       0             0
# 72       0             7        5        42        0       0             0
# 73       0            19        8        38        0       0             1
# 74       0             3        2        24        0       0             1
# 75       0             2        1        19        0       0             0
# 76       0             3        3        18        0       0             0
# 77       0             6        4        20        0       0             0
# 78       0             1        1         8        0       0             0
# 79       0             0        0         0        0       0             0
#
#    Position Season
# 0        QB   2010
# 1        QB   2010
# 2        QB   2010
# 3        QB   2010
# 4        QB   2010
# 5        QB   2010
# 6        QB   2010
# 7        QB   2010
# 8        QB   2010
# 9        QB   2010
# 10       QB   2010
# 11       QB   2010
# 12       QB   2010
# 13       QB   2010
# 14       QB   2010
# 15       QB   2010
# 16       QB   2010
# 17       QB   2010
# 18       QB   2010
# 19       QB   2010
# 20       QB   2010
# 21       QB   2010
# 22       QB   2010
# 23       QB   2010
# 24       QB   2010
# 25       QB   2010
# 26       QB   2010
# 27       QB   2010
# 28       QB   2010
# 29       QB   2010
# ..      ...    ...
# 50       QB   2010
# 51       QB   2010
# 52       QB   2010
# 53       QB   2010
# 54       QB   2010
# 55       QB   2010
# 56       QB   2010
# 57       QB   2010
# 58       QB   2010
# 59       QB   2010
# 60       QB   2010
# 61       QB   2010
# 62       QB   2010
# 63       QB   2010
# 64       QB   2010
# 65       QB   2010
# 66       QB   2010
# 67       QB   2010
# 68       QB   2010
# 69       QB   2010
# 70       QB   2010
# 71       QB   2010
# 72       QB   2010
# 73       QB   2010
# 74       QB   2010
# 75       QB   2010
# 76       QB   2010
# 77       QB   2010
# 78       QB   2010
# 79       QB   2010
#
# [80 rows x 17 columns]
